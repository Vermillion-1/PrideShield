# %%
# prompt: write pandas code to import and read a csv

import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('/content/Ann-1_img - Ann-1_add.csv')

# You can now work with the DataFrame 'df'
# For example, to display the first 5 rows:
print(df.head())

# %%
# prompt: add a new column named id which will hold integer values to this df, the values in this column should be the value in 'filename' column with the text before the underscore, the underscore and the extension removed

import pandas as pd


# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('/content/Ann-1_img - Ann-1_add.csv')

# Extract the ID from the 'filename' column
filename_entry = df['Filename'][0]
name = filename_entry.split('_')
number = name[1].split('.')[0]

# You can now work with the DataFrame 'df'
# For example, to display the first 5 rows:
print(number)

# %%
id_value

# %%
# Define a function to extract the ID
def extract_id(filename):
    name = filename.split('_')
    number = name[1].split('.')[0]
    return number

# Apply the function to the 'Filename' column and create the 'id' column
df['id'] = df['Filename'].apply(extract_id)

# Print the updated DataFrame
print(df)

# %%
# prompt: store df as a csv

import pandas as pd

# Assuming 'df' is already defined and populated as in your original code
# ... (your existing code to create and modify the DataFrame) ...

# Specify the desired output file path
output_file_path = '/content/output.csv'  # Or any other desired path

# Store the DataFrame as a CSV file
df.to_csv(output_file_path, index=False) # index=False prevents writing row indices to the file
